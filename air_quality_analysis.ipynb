# %% [markdown]
# <a href="https://colab.research.google.com/github/premt99/Internship_Project/blob/main/air_quality_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Line Chart for all

# %%
import pandas as pd
import plotly.graph_objects as go

# Load dataset
file_path = "/content/AT.xlsx"  # Adjust if needed
df = pd.read_excel(file_path)

# 🔹 Convert 'Date' and 'Time' into a single 'DateTime' column
df['DateTime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'].astype(str), errors='coerce')

# 🔹 Set 'DateTime' as index
df.set_index('DateTime', inplace=True)

# 🔹 Select pollutants to plot
pollutants = {
    'PM2.5': 60,
    'PM10': 100,
    'NO': 80,
    'NO2': 80,
    'NOx': 80,
    'NH3': 400,
    'SO2': 80,
    'CO': 4,
    'Ozone': 180
}

# Create figure
fig = go.Figure()

# Add pollution lines
for pollutant, limit in pollutants.items():
    if pollutant in df.columns:
        fig.add_trace(go.Scatter(x=df.index, y=df[pollutant], mode='lines', name=pollutant))

# Add threshold lines
for pollutant, limit in pollutants.items():
    fig.add_trace(go.Scatter(x=[df.index.min(), df.index.max()], y=[limit, limit],
                             mode='lines', name=f"{pollutant} Limit", line=dict(dash='dash')))

# Customize layout
fig.update_layout(title="Pollution Levels vs Prescribed Standards",
                  xaxis_title="Date",
                  yaxis_title="Pollution Level",
                  hovermode="x unified")

# Show chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# PM2.5

# %%
# ✅ Install necessary library for interactive plots
# !pip install plotly

import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
from google.colab import files

# 🔹 Upload file manually if not using Google Drive
uploaded = files.upload()
file_path = "New Filtered Data.xlsx"  # Change if needed

# 🔹 Read Excel File
df = pd.read_excel(file_path)

# 🔹 Convert 'Date' and 'Time' into a single 'DateTime' column
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')  # Convert Date
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S', errors='coerce').dt.time  # Convert Time
df['DateTime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'].astype(str), errors='coerce')

# 🔹 Remove missing values
df = df.dropna(subset=['DateTime', 'PM2.5'])

# 🔹 Set 'DateTime' as index for time-series plotting
df = df.set_index('DateTime')

# 🔹 Prescribed PM2.5 Range (0-60)
pm25_min, pm25_max = 0, 60

# ✅ Interactive Line Chart using Plotly
fig = px.line(df, x=df.index, y='PM2.5', title="PM2.5 Levels Over Time",
              labels={'PM2.5': 'PM2.5 (µg/m³)', 'DateTime': 'Date & Time'},
              template="plotly_dark")

# 🔹 Add prescribed range (shaded area)
fig.add_hrect(y0=pm25_min, y1=pm25_max, line_width=0, fillcolor="green", opacity=0.2)

# ✅ Show Interactive Chart
fig.show()
# Out:
# ...
#      <input type="file" id="files-85e85fb9-e5e2-46de-aeec-6e1412570d92" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85e85fb9-e5e2-46de-aeec-6e1412570d92">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# PM10

# %%
# ✅ Install necessary libraries


import pandas as pd
import plotly.express as px
from google.colab import files

# 🔹 Upload file manually
uploaded = files.upload()
file_path = list(uploaded.keys())[0]  # Auto-detect uploaded file

# 🔹 Read Excel File
df = pd.read_excel(file_path)

# 🔹 Convert 'Date' and 'Time' into a single 'DateTime' column
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')  # Convert Date
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S', errors='coerce').dt.time  # Convert Time
df['DateTime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'].astype(str), errors='coerce')

# 🔹 Remove missing values
df = df.dropna(subset=['DateTime', 'PM10'])

# 🔹 Set 'DateTime' as index for time-series plotting
df = df.set_index('DateTime')

# ✅ Interactive Line Chart for PM10
fig = px.line(df, x=df.index, y='PM10', title="PM10 Levels Over Time",
              labels={'PM10': 'PM10 (µg/m³)', 'DateTime': 'Date & Time'},
              template="plotly_dark")

# 🔹 Prescribed PM10 Range (0-100)
pm10_min, pm10_max = 0, 100
fig.add_hrect(y0=pm10_min, y1=pm10_max, line_width=0, fillcolor="green", opacity=0.2)

# ✅ Show Interactive Chart
fig.show()
# Out:
#      <input type="file" id="files-0a52b8b6-bca0-48fc-9c85-73e1c5e475b8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0a52b8b6-bca0-48fc-9c85-73e1c5e475b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# NO

# %%
# ✅ Install necessary libraries


import pandas as pd
import plotly.express as px
from google.colab import files

# 🔹 Upload file manually
uploaded = files.upload()
file_path = list(uploaded.keys())[0]  # Auto-detect uploaded file

# 🔹 Read Excel File
df = pd.read_excel(file_path)

# 🔹 Convert 'Date' and 'Time' into a single 'DateTime' column
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')  # Convert Date
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S', errors='coerce').dt.time  # Convert Time
df['DateTime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'].astype(str), errors='coerce')

# 🔹 Remove missing values
df = df.dropna(subset=['DateTime', 'NO'])

# 🔹 Set 'DateTime' as index for time-series plotting
df = df.set_index('DateTime')

# ✅ Interactive Line Chart for NO
fig = px.line(df, x=df.index, y='NO', title="NO Levels Over Time",
              labels={'NO': 'NO (µg/m³)', 'DateTime': 'Date & Time'},
              template="plotly_dark")

# 🔹 Prescribed NO Range (0-40) - Adjust based on air quality guidelines
no_min, no_max = 0, 40
fig.add_hrect(y0=no_min, y1=no_max, line_width=0, fillcolor="green", opacity=0.2)

# ✅ Show Interactive Chart
fig.show()
# Out:
#      <input type="file" id="files-7874ec17-1978-4ca7-9bb5-f6899699b51d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7874ec17-1978-4ca7-9bb5-f6899699b51d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# NO2

# %%
# ✅ Install necessary libraries

import pandas as pd
import plotly.express as px
from google.colab import files

# 🔹 Upload file manually
uploaded = files.upload()
file_path = list(uploaded.keys())[0]  # Auto-detect uploaded file

# 🔹 Read Excel File
df = pd.read_excel(file_path)

# 🔹 Convert 'Date' and 'Time' into a single 'DateTime' column
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')  # Convert Date
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S', errors='coerce').dt.time  # Convert Time
df['DateTime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'].astype(str), errors='coerce')

# 🔹 Remove missing values
df = df.dropna(subset=['DateTime', 'NO2'])

# 🔹 Set 'DateTime' as index for time-series plotting
df = df.set_index('DateTime')

# ✅ Interactive Line Chart for NO2
fig = px.line(df, x=df.index, y='NO2', title="NO₂ Levels Over Time",
              labels={'NO2': 'NO₂ (µg/m³)', 'DateTime': 'Date & Time'},
              template="plotly_dark")

# 🔹 Prescribed NO₂ Range (0-40) - Adjust based on air quality guidelines
no2_min, no2_max = 0, 40
fig.add_hrect(y0=no2_min, y1=no2_max, line_width=0, fillcolor="green", opacity=0.2)

# ✅ Show Interactive Chart
fig.show()
# Out:
#      <input type="file" id="files-de3728d0-1619-45c1-bc6c-dcaabca4c5fa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-de3728d0-1619-45c1-bc6c-dcaabca4c5fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# NOx

# %%
# ✅ Install necessary libraries


import pandas as pd
import plotly.express as px
from google.colab import files

# 🔹 Upload file manually
uploaded = files.upload()
file_path = list(uploaded.keys())[0]  # Auto-detect uploaded file

# 🔹 Read Excel File
df = pd.read_excel(file_path)

# 🔹 Convert 'Date' and 'Time' into a single 'DateTime' column
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')  # Convert Date
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S', errors='coerce').dt.time  # Convert Time
df['DateTime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'].astype(str), errors='coerce')

# 🔹 Remove missing values
df = df.dropna(subset=['DateTime', 'NOx'])

# 🔹 Set 'DateTime' as index for time-series plotting
df = df.set_index('DateTime')

# ✅ Interactive Line Chart for NOx
fig = px.line(df, x=df.index, y='NOx', title="NOx Levels Over Time",
              labels={'NOx': 'NOx (µg/m³)', 'DateTime': 'Date & Time'},
              template="plotly_dark")

# 🔹 Prescribed NOx Range (0-50) - Adjust as per air quality guidelines
nox_min, nox_max = 0, 50
fig.add_hrect(y0=nox_min, y1=nox_max, line_width=0, fillcolor="green", opacity=0.2)

# ✅ Show Interactive Chart
fig.show()
# Out:
#      <input type="file" id="files-bc8afa15-62b8-47e3-bc11-bcf4b3000879" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bc8afa15-62b8-47e3-bc11-bcf4b3000879">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# NH3

# %%
# ✅ Install necessary libraries

import pandas as pd
import plotly.express as px
from google.colab import files

# 🔹 Upload file manually
uploaded = files.upload()
file_path = list(uploaded.keys())[0]  # Auto-detect uploaded file

# 🔹 Read Excel File
df = pd.read_excel(file_path)

# 🔹 Convert 'Date' and 'Time' into a single 'DateTime' column
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')  # Convert Date
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S', errors='coerce').dt.time  # Convert Time
df['DateTime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'].astype(str), errors='coerce')

# 🔹 Remove missing values
df = df.dropna(subset=['DateTime', 'NH3'])

# 🔹 Set 'DateTime' as index for time-series plotting
df = df.set_index('DateTime')

# ✅ Interactive Line Chart for NH₃
fig = px.line(df, x=df.index, y='NH3', title="NH₃ Levels Over Time",
              labels={'NH3': 'NH₃ (µg/m³)', 'DateTime': 'Date & Time'},
              template="plotly_dark")

# 🔹 Prescribed NH₃ Range (0-400) - Adjust as per air quality guidelines
nh3_min, nh3_max = 0, 400
fig.add_hrect(y0=nh3_min, y1=nh3_max, line_width=0, fillcolor="green", opacity=0.2)

# ✅ Show Interactive Chart
fig.show()
# Out:
#      <input type="file" id="files-55c830b3-4af4-495a-9b9f-699d30bc2a4b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-55c830b3-4af4-495a-9b9f-699d30bc2a4b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# SO2

# %%
# ✅ Install necessary libraries


import pandas as pd
import plotly.express as px
from google.colab import files

# 🔹 Upload file manually
uploaded = files.upload()
file_path = list(uploaded.keys())[0]  # Auto-detect uploaded file

# 🔹 Read Excel File
df = pd.read_excel(file_path)

# 🔹 Convert 'Date' and 'Time' into a single 'DateTime' column
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')  # Convert Date
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S', errors='coerce').dt.time  # Convert Time
df['DateTime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'].astype(str), errors='coerce')

# 🔹 Remove missing values
df = df.dropna(subset=['DateTime', 'SO2'])

# 🔹 Set 'DateTime' as index for time-series plotting
df = df.set_index('DateTime')

# ✅ Interactive Line Chart for SO₂
fig = px.line(df, x=df.index, y='SO2', title="SO₂ Levels Over Time",
              labels={'SO2': 'SO₂ (µg/m³)', 'DateTime': 'Date & Time'},
              template="plotly_dark")

# 🔹 Prescribed SO₂ Range (0-80) - Adjust as per air quality guidelines
so2_min, so2_max = 0, 80
fig.add_hrect(y0=so2_min, y1=so2_max, line_width=0, fillcolor="green", opacity=0.2)

# ✅ Show Interactive Chart
fig.show()
# Out:
#      <input type="file" id="files-5a8775ac-2fec-46c5-8884-d9a6c2bdbf73" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5a8775ac-2fec-46c5-8884-d9a6c2bdbf73">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# CO

# %%
# ✅ Install necessary libraries

import pandas as pd
import plotly.express as px
from google.colab import files

# 🔹 Upload file manually
uploaded = files.upload()
file_path = list(uploaded.keys())[0]  # Auto-detect uploaded file

# 🔹 Read Excel File
df = pd.read_excel(file_path)

# 🔹 Convert 'Date' and 'Time' into a single 'DateTime' column
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')  # Convert Date
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S', errors='coerce').dt.time  # Convert Time
df['DateTime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'].astype(str), errors='coerce')

# 🔹 Remove missing values
df = df.dropna(subset=['DateTime', 'CO'])

# 🔹 Set 'DateTime' as index for time-series plotting
df = df.set_index('DateTime')

# ✅ Interactive Line Chart for CO
fig = px.line(df, x=df.index, y='CO', title="CO Levels Over Time",
              labels={'CO': 'CO (mg/m³)', 'DateTime': 'Date & Time'},
              template="plotly_dark")

# 🔹 Prescribed CO Range (0-4) mg/m³ (As per air quality guidelines)
co_min, co_max = 0, 4
fig.add_hrect(y0=co_min, y1=co_max, line_width=0, fillcolor="green", opacity=0.2)

# ✅ Show Interactive Chart
fig.show()
# Out:
#      <input type="file" id="files-135b8152-379f-4eb8-98a1-5bf835b8cd3e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-135b8152-379f-4eb8-98a1-5bf835b8cd3e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Ozone

# %%
# ✅ Install necessary libraries

import pandas as pd
import plotly.express as px
from google.colab import files

# 🔹 Upload file manually
uploaded = files.upload()
file_path = list(uploaded.keys())[0]  # Auto-detect uploaded file

# 🔹 Read Excel File
df = pd.read_excel(file_path)

# 🔹 Convert 'Date' and 'Time' into a single 'DateTime' column
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')  # Convert Date
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S', errors='coerce').dt.time  # Convert Time
df['DateTime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'].astype(str), errors='coerce')

# 🔹 Remove missing values
df = df.dropna(subset=['DateTime', 'Ozone'])

# 🔹 Set 'DateTime' as index for time-series plotting
df = df.set_index('DateTime')

# ✅ Interactive Line Chart for Ozone (O₃)
fig = px.line(df, x=df.index, y='Ozone', title="Ozone (O₃) Levels Over Time",
              labels={'Ozone': 'O₃ (µg/m³)', 'DateTime': 'Date & Time'},
              template="plotly_dark")

# 🔹 Prescribed O₃ Range (0-100) µg/m³ (As per air quality guidelines)
o3_min, o3_max = 0, 100
fig.add_hrect(y0=o3_min, y1=o3_max, line_width=0, fillcolor="green", opacity=0.2)

# ✅ Show Interactive Chart
fig.show()
# Out:
#      <input type="file" id="files-bc52d3b6-df6d-4a34-95bb-25e4df81c428" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bc52d3b6-df6d-4a34-95bb-25e4df81c428">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# RH

# %%
# ✅ Install necessary libraries


import pandas as pd
import plotly.express as px
from google.colab import files

# 🔹 Upload file manually
uploaded = files.upload()
file_path = list(uploaded.keys())[0]

# 🔹 Read Excel File
df = pd.read_excel(file_path)

# 🔹 Convert 'Date' and 'Time' into a single 'DateTime' column
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S', errors='coerce').dt.time
df['DateTime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'].astype(str), errors='coerce')

# 🔹 Remove missing values
df = df.dropna(subset=['DateTime', 'RH'])

# 🔹 Set 'DateTime' as index
df = df.set_index('DateTime')

# ✅ Interactive Line Chart for RH
fig = px.line(df, x=df.index, y='RH', title="Relative Humidity (RH) Levels Over Time",
              labels={'RH': 'RH (%)', 'DateTime': 'Date & Time'},
              template="plotly_dark")

# ✅ Show Interactive Chart
fig.show()
# Out:
#      <input type="file" id="files-b4f07402-63bf-46c9-a1c7-be79a2813c96" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b4f07402-63bf-46c9-a1c7-be79a2813c96">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# WS

# %%
# ✅ Install necessary libraries

import pandas as pd
import plotly.express as px
from google.colab import files

# 🔹 Upload file manually
uploaded = files.upload()
file_path = list(uploaded.keys())[0]

# 🔹 Read Excel File
df = pd.read_excel(file_path)

# 🔹 Convert 'Date' and 'Time' into a single 'DateTime' column
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S', errors='coerce').dt.time
df['DateTime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'].astype(str), errors='coerce')

# 🔹 Remove missing values
df = df.dropna(subset=['DateTime', 'WS'])

# 🔹 Set 'DateTime' as index
df = df.set_index('DateTime')

# ✅ Interactive Line Chart for WS
fig = px.line(df, x=df.index, y='WS', title="Wind Speed (WS) Over Time",
              labels={'WS': 'WS (m/s)', 'DateTime': 'Date & Time'},
              template="plotly_dark")

# ✅ Show Interactive Chart
fig.show()
# Out:
#      <input type="file" id="files-b30bdad2-2175-4444-a176-350678618e95" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b30bdad2-2175-4444-a176-350678618e95">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# WD

# %%
# ✅ Install necessary libraries

import pandas as pd
import plotly.express as px
from google.colab import files

# 🔹 Upload file manually
uploaded = files.upload()
file_path = list(uploaded.keys())[0]

# 🔹 Read Excel File
df = pd.read_excel(file_path)

# 🔹 Convert 'Date' and 'Time' into a single 'DateTime' column
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S', errors='coerce').dt.time
df['DateTime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'].astype(str), errors='coerce')

# 🔹 Remove missing values
df = df.dropna(subset=['DateTime', 'WD'])

# 🔹 Set 'DateTime' as index
df = df.set_index('DateTime')

# ✅ Interactive Line Chart for WD
fig = px.line(df, x=df.index, y='WD', title="Wind Direction (WD) Over Time",
              labels={'WD': 'WD (°)', 'DateTime': 'Date & Time'},
              template="plotly_dark")

# ✅ Show Interactive Chart
fig.show()
# Out:
#      <input type="file" id="files-967fa220-010b-47a1-acf0-22b239299a2f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-967fa220-010b-47a1-acf0-22b239299a2f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# SR

# %%
# ✅ Install necessary libraries

import pandas as pd
import plotly.express as px
from google.colab import files

# 🔹 Upload file manually
uploaded = files.upload()
file_path = list(uploaded.keys())[0]

# 🔹 Read Excel File
df = pd.read_excel(file_path)

# 🔹 Convert 'Date' and 'Time' into a single 'DateTime' column
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S', errors='coerce').dt.time
df['DateTime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'].astype(str), errors='coerce')

# 🔹 Remove missing values
df = df.dropna(subset=['DateTime', 'SR'])

# 🔹 Set 'DateTime' as index
df = df.set_index('DateTime')

# ✅ Interactive Line Chart for SR
fig = px.line(df, x=df.index, y='SR', title="Solar Radiation (SR) Over Time",
              labels={'SR': 'SR (W/m²)', 'DateTime': 'Date & Time'},
              template="plotly_dark")

# ✅ Show Interactive Chart
fig.show()
# Out:
#      <input type="file" id="files-56a275e0-0736-47c3-a2b7-898eb4420347" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-56a275e0-0736-47c3-a2b7-898eb4420347">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# BR(Barometric Pressure)

# %%
# ✅ Install necessary libraries

import pandas as pd
import plotly.express as px
from google.colab import files

# 🔹 Upload file manually
uploaded = files.upload()
file_path = list(uploaded.keys())[0]

# 🔹 Read Excel File
df = pd.read_excel(file_path)

# 🔹 Convert 'Date' and 'Time' into a single 'DateTime' column
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S', errors='coerce').dt.time
df['DateTime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'].astype(str), errors='coerce')

# 🔹 Remove missing values
df = df.dropna(subset=['DateTime', 'BP'])

# 🔹 Set 'DateTime' as index
df = df.set_index('DateTime')

# ✅ Interactive Line Chart for BP
fig = px.line(df, x=df.index, y='BP', title="Barometric Pressure (BP) Over Time",
              labels={'BP': 'BP (hPa)', 'DateTime': 'Date & Time'},
              template="plotly_dark")

# ✅ Show Interactive Chart
fig.show()
# Out:
#      <input type="file" id="files-b2c5880d-4362-4b5e-8db9-80eda92cc199" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b2c5880d-4362-4b5e-8db9-80eda92cc199">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# AT(Air Temprature)

# %%
# ✅ Install necessary libraries


import pandas as pd
import plotly.express as px
from google.colab import files

# 🔹 Upload file manually
uploaded = files.upload()
file_path = list(uploaded.keys())[0]

# 🔹 Read Excel File
df = pd.read_excel(file_path)

# 🔹 Convert 'Date' and 'Time' into a single 'DateTime' column
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S', errors='coerce').dt.time
df['DateTime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'].astype(str), errors='coerce')

# 🔹 Remove missing values
df = df.dropna(subset=['DateTime', 'AT'])

# 🔹 Set 'DateTime' as index
df = df.set_index('DateTime')

# ✅ Interactive Line Chart for AT
fig = px.line(df, x=df.index, y='AT', title="Air Temperature (AT) Over Time",
              labels={'AT': 'AT (°C)', 'DateTime': 'Date & Time'},
              template="plotly_dark")

# ✅ Show Interactive Chart
fig.show()
# Out:
#      <input type="file" id="files-466113f1-6c0f-4148-83f0-83552d56b220" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-466113f1-6c0f-4148-83f0-83552d56b220">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
